# %%
import pandas as pd
import quandl
import pickle
df=quandl.get("FMAC/HPI", authtoken="enter_ur_token", start_date="2002-01-30")
pickle_out=open('states.pickle','wb')
pickle.dump(df,pickle_out)
pickle_out.close()

# %%
pickle_in=open('states.pickle','rb')
HPI_data=pickle.load(pickle_in)
print(HPI_data)
# Out:
#                     AK          AL          AR          AZ          CA  \
# Date
# 2002-01-31  106.548227  102.288922  103.559310  105.640246  110.596125
# 2002-02-28  107.146447  102.500025  104.015976  106.289956  111.922845
# 2002-03-31  108.005542  102.870529  104.416913  107.094600  113.968209
# 2002-04-30  109.084834  103.428889  104.859899  107.903536  116.259369
# 2002-05-31  110.132373  104.064995  105.522252  108.575424  118.408598
# 2002-06-30  110.931623  104.493779  106.227385  109.137137  120.525742
# 2002-07-31  111.511413  104.820019  106.682714  109.791670  122.617415
# 2002-08-31  111.841229  105.091450  106.775028  110.467947  124.333763
# 2002-09-30  111.932616  105.218683  106.796418  111.215616  125.630487
# 2002-10-31  111.990472  105.513757  107.050499  111.911113  126.851614
# 2002-11-30  112.219374  105.911787  107.345602  112.342874  127.755153
# 2002-12-31  112.705052  106.131734  107.549453  112.586976  128.752495
# ...
